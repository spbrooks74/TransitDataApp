# %%
mbtaURL = "https://api-v3.mbta.com/vehicles?filter[route]=1&include=trip"

import urllib.request, json
with urllib.request.urlopen(mbtaURL) as url:
    data = json.loads(url.read().decode())
   
    with open('data.json', 'w') as outfile:
        json.dump(data, outfile)
   
    with open('data.txt', 'w') as outfile:
        json.dump(json.dumps(data, indent=4, sort_keys=True), outfile)
       
    print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "data": [
#         {
#             "attributes": {
#                 "bearing": 82,
#                 "carriages": [],
#                 "current_status": "STOPPED_AT",
#                 "current_stop_sequence": 1,
#                 "direction_id": 0,
#                 "label": "1899",
#                 "latitude": 42.329860779,
#                 "longitude": -71.08351094,
#                 "occupancy_status": "FEW_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2024-02-28T16:07:16-05:00"
#             },
#             "id": "y1899",
#             "links": {
#                 "self": "/vehicles/y1899"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "64",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "60168565",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 0,
#                 "carriages": [],
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 13,
#                 "direction_id": 0,
#                 "label": "1895",
#                 "latitude": 42.34642306,
#                 "longitude": -71.08715943,
#                 "occupancy_status": null,
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2024-02-28T16:06:20-05:00"
#             },
#             "id": "y1895",
#             "links": {
#                 "self": "/vehicles/y1895"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "93",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "60168562",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 137,
#                 "carriages": [],
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 10,
#                 "direction_id": 1,
#                 "label": "1885",
#                 "latitude": 42.35962498,
#                 "longitude": -71.09409859,
#                 "occupancy_status": "FEW_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2024-02-28T16:07:16-05:00"
#             },
#             "id": "y1885",
#             "links": {
#                 "self": "/vehicles/y1885"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "75",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "60169014",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 0,
#                 "carriages": [],
#                 "current_status": "STOPPED_AT",
#                 "current_stop_sequence": 1,
#                 "direction_id": 0,
#                 "label": "1877",
#                 "latitude": 42.32988296,
#                 "longitude": -71.08415013,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2024-02-28T16:07:17-05:00"
#             },
#             "id": "y1877",
#             "links": {
#                 "self": "/vehicles/y1877"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "64",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "60168572",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 185,
#                 "carriages": [],
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 17,
#                 "direction_id": 1,
#                 "label": "1857",
#                 "latitude": 42.33743089,
#                 "longitude": -71.07818326,
#                 "occupancy_status": "FEW_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2024-02-28T16:07:11-05:00"
#             },
#             "id": "y1857",
#             "links": {
#                 "self": "/vehicles/y1857"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "59",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "60169013",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 0,
#                 "carriages": [],
#                 "current_status": "STOPPED_AT",
#                 "current_stop_sequence": 1,
#                 "direction_id": 0,
#                 "label": "1816",
#                 "latitude": 42.32990629,
#                 "longitude": -71.084183309,
#                 "occupancy_status": "FULL",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2024-02-28T16:06:56-05:00"
#             },
#             "id": "y1816",
#             "links": {
#                 "self": "/vehicles/y1816"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "64",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "60168567",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 280,
#                 "carriages": [],
#                 "current_status": "STOPPED_AT",
#                 "current_stop_sequence": 22,
#                 "direction_id": 0,
#                 "label": "1780",
#                 "latitude": 42.3702406,
#                 "longitude": -71.11331762,
#                 "occupancy_status": "FEW_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2024-02-28T16:07:15-05:00"
#             },
#             "id": "y1780",
#             "links": {
#                 "self": "/vehicles/y1780"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "108",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "60168551",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 225,
#                 "carriages": [],
#                 "current_status": "STOPPED_AT",
#                 "current_stop_sequence": 1,
#                 "direction_id": 0,
#                 "label": "1759",
#                 "latitude": 42.33002,
#                 "longitude": -71.08433,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2024-02-28T16:07:12-05:00"
#             },
#             "id": "y1759",
#             "links": {
#                 "self": "/vehicles/y1759"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "64",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "60168570",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 301,
#                 "carriages": [],
#                 "current_status": "STOPPED_AT",
#                 "current_stop_sequence": 19,
#                 "direction_id": 0,
#                 "label": "1740",
#                 "latitude": 42.36679386,
#                 "longitude": -71.106009699,
#                 "occupancy_status": "FEW_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2024-02-28T16:07:15-05:00"
#             },
#             "id": "y1740",
#             "links": {
#                 "self": "/vehicles/y1740"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "104",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "60168554",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         }
#     ],
#     "included": [
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-1",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "60168551",
#             "links": {
#                 "self": "/trips/60168551"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS12024-hbc14011-Weekday-02",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010128",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-2",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "60168554",
#             "links": {
#                 "self": "/trips/60168554"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS12024-hbc14011-Weekday-02",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010128",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-4",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "60168562",
#             "links": {
#                 "self": "/trips/60168562"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS12024-hbc14011-Weekday-02",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010128",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-5",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "60168565",
#             "links": {
#                 "self": "/trips/60168565"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS12024-hbc14011-Weekday-02",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010128",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-6",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "60168567",
#             "links": {
#                 "self": "/trips/60168567"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS12024-hbc14011-Weekday-02",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010128",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-11",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "60168570",
#             "links": {
#                 "self": "/trips/60168570"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS12024-hbc14011-Weekday-02",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010128",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-8",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "60168572",
#             "links": {
#                 "self": "/trips/60168572"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS12024-hbc14011-Weekday-02",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010128",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-9",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "60169013",
#             "links": {
#                 "self": "/trips/60169013"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS12024-hbc14011-Weekday-02",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010129",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-10",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "60169014",
#             "links": {
#                 "self": "/trips/60169014"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS12024-hbc14011-Weekday-02",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010129",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         }
#     ],
#     "jsonapi": {
#         "version": "1.0"
#     }
# }
